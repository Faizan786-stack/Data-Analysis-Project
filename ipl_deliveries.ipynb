# %%
import pandas as pd

# %%
df = pd.read_csv('deliveries.csv')

# %%
df
# Out:
#        match_no          date           stage  \
# 0             1  Mar 22, 2025    League stage
# 1             1  Mar 22, 2025    League stage
# 2             1  Mar 22, 2025    League stage
# 3             1  Mar 22, 2025    League stage
# 4             1  Mar 22, 2025    League stage
# ...         ...           ...             ...
# 17178        74  Jun 03, 2025  Playoffs stage
# 17179        74  Jun 03, 2025  Playoffs stage
# 17180        74  Jun 03, 2025  Playoffs stage
# 17181        74  Jun 03, 2025  Playoffs stage
# 17182        74  Jun 03, 2025  Playoffs stage
#
#                                   venue batting_team bowling_team  innings  \
# 0                 Eden Gardens, Kolkata          KKR          RCB        1
# 1                 Eden Gardens, Kolkata          KKR          RCB        1
# 2                 Eden Gardens, Kolkata          KKR          RCB        1
# 3                 Eden Gardens, Kolkata          KKR          RCB        1
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        match_no          date           stage  \
# 0             1  Mar 22, 2025    League stage
# 1             1  Mar 22, 2025    League stage
# 2             1  Mar 22, 2025    League stage
# 3             1  Mar 22, 2025    League stage
# 4             1  Mar 22, 2025    League stage
# ...         ...           ...             ...
# 17178        74  Jun 03, 2025  Playoffs stage
# 17179        74  Jun 03, 2025  Playoffs stage
# 17180        74  Jun 03, 2025  Playoffs stage
# 17181        74  Jun 03, 2025  Playoffs stage
# 17182        74  Jun 03, 2025  Playoffs stage
#
#                                   venue batting_team bowling_team  innings  \
# 0                 Eden Gardens, Kolkata          KKR          RCB        1
# 1                 Eden Gardens, Kolkata          KKR          RCB        1
# 2                 Eden Gardens, Kolkata          KKR          RCB        1
# ...

# %%
df.columns
# Out:
# Index(['match_no', 'date', 'stage', 'venue', 'batting_team', 'bowling_team',
#        'innings', 'over', 'striker', 'bowler', 'runs_of_bat', 'extras', 'wide',
#        'legbyes', 'byes', 'noballs', 'wicket_type', 'player_dismissed',
#        'fielder'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    match_no          date         stage                  venue batting_team  \
# 0         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 1         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 2         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 3         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 4         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 5         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 6         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 7         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 8         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 9         1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
#
#   bowling_team  innings  over  striker      bowler  runs_of_bat  extras  wide  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['match_no', 'date', 'stage', 'venue', 'batting_team', 'bowling_team', 'innings', 'over', 'striker', 'bowler', 'runs_of_bat', 'extras', 'wide', 'legbyes', 'byes', 'noballs', 'wicket_type', 'player_dismissed', 'fielder']

# %%
df2 = df.drop(['stage','extras','legbyes','byes','noballs'], axis=1)
df2.head()
# Out:
#    match_no          date                  venue batting_team bowling_team  \
# 0         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
# 1         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
# 2         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
# 3         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
# 4         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
#
#    innings  over  striker     bowler  runs_of_bat  wide wicket_type  \
# 0        1   0.1  de Kock  Hazlewood            0     0         NaN
# 1        1   0.2  de Kock  Hazlewood            4     0         NaN
# 2        1   0.3  de Kock  Hazlewood            0     0         NaN
# 3        1   0.4  de Kock  Hazlewood            0     0         NaN
# 4        1   0.5  de Kock  Hazlewood            0     0      caught
#
#   player_dismissed        fielder
# 0              NaN            NaN
# 1              NaN            NaN
# ...

# %% [markdown]
# ## Which batsman scored the most runs?

# %%
most_run = df2[('striker')].value_counts()
most_run
# Out:
# striker
# Sai Sudharsan          509
# Kohli                  466
# Suryakumar Yadav       439
# Shubman Gill           432
# Mitchell Marsh         400
#                       ...
# Anukul Roy               1
# Bumrah                   1
# Ferguson                 1
# Livingstone 1 run        1
# Varun Chakaravarthy      1
# Name: count, Length: 168, dtype: int64

# %%
most_run.max()
# Out:
# 509

# %%
most_run.min()
# Out:
# 1

# %%
most_run = most_run.sort_values(ascending=False)

# %%
most_run
# Out:
# striker
# Sai Sudharsan          509
# Kohli                  466
# Suryakumar Yadav       439
# Shubman Gill           432
# Mitchell Marsh         400
#                       ...
# Anukul Roy               1
# Bumrah                   1
# Ferguson                 1
# Livingstone 1 run        1
# Varun Chakaravarthy      1
# Name: count, Length: 168, dtype: int64

# %%
most_run.tail(10)
# Out:
# striker
# Ngidi                  2
# Mustafizur             1
# Satyanarayana Raju     1
# Karn Sharma            1
# Hazlewood              1
# Anukul Roy             1
# Bumrah                 1
# Ferguson               1
# Livingstone 1 run      1
# Varun Chakaravarthy    1
# Name: count, dtype: int64

# %%
MR = most_run.drop_duplicates().head()

# %%
MR
# Out:
# striker
# Sai Sudharsan       509
# Kohli               466
# Suryakumar Yadav    439
# Shubman Gill        432
# Mitchell Marsh      400
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.barh(MR.index, MR.values, color='#54f3e0')
plt.title('MOST RUN OF THE BATSMAN')
plt.xlabel('Runs')
plt.ylabel('Player Name')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Which bowler has the most wickets?

# %%
df2.fillna(0).head()
# Out:
#    match_no          date                  venue batting_team bowling_team  \
# 0         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
# 1         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
# 2         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
# 3         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
# 4         1  Mar 22, 2025  Eden Gardens, Kolkata          KKR          RCB
#
#    innings  over  striker     bowler  runs_of_bat  wide wicket_type  \
# 0        1   0.1  de Kock  Hazlewood            0     0           0
# 1        1   0.2  de Kock  Hazlewood            4     0           0
# 2        1   0.3  de Kock  Hazlewood            0     0           0
# 3        1   0.4  de Kock  Hazlewood            0     0           0
# 4        1   0.5  de Kock  Hazlewood            0     0      caught
#
#   player_dismissed        fielder
# 0                0              0
# 1                0              0
# ...

# %%
wikets = df2.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False)
wikets
# Out:
# bowler
# Prasidh           26
# Noor Ahmad        24
# Boult             23
# Hazlewood         22
# Arshdeep Singh    22
#                   ..
# Sandeep            0
# Shashank Singh     0
# Shivam Dube        0
# Stubbs             0
# Mulder             0
# Name: player_dismissed, Length: 128, dtype: int64

# %%
top_wikets = wikets.drop_duplicates().head(10)
top_wikets
# Out:
# bowler
# Prasidh                26
# Noor Ahmad             24
# Boult                  23
# Hazlewood              22
# Bumrah                 21
# Mitchell Starc         19
# Bhuvneshwar            18
# Varun Chakaravarthy    17
# Siraj                  16
# Thakur                 15
# Name: player_dismissed, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(top_wikets.index, top_wikets.values, color='#55f731')
plt.title('Top 10 Most Of The Wickets')
plt.xlabel('Bowlers')
plt.ylabel('Wickets')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Who took the most catches/runouts/stumpings?

# %%
wicket_type = df2['wicket_type'].value_counts()

# %%
wicket_type
# Out:
# wicket_type
# caught          622
# bowled          133
# lbw              53
# runout           39
# stumped          18
# hit wicket        3
# retired out       2
# retired hurt      2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.bar(wicket_type.index, wicket_type.values, color='#f7af31')
for i in range(len(wicket_type)):
    plt.text(i, wicket_type.values[i] + 10, str(wicket_type.values[i]), ha='center')
plt.title('most catches/runouts/stumpings')
plt.xlabel('Wickets Type')
plt.ylabel('Number Of Wickets')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Which bowlers have the most dot balls in the powerplay (overs 1–6)?

# %%
power_play = df2[df2['over'].between(1,6)]
dot_balls = power_play[power_play['runs_of_bat'] == 0]
dot_balls_counts = dot_balls.groupby('bowler').size().reset_index(name='dot_balls')
top_dots =  dot_balls_counts.sort_values(by='dot_balls', ascending=False)

# %%
most_dots = top_dots.head(10).reset_index().drop('index', axis=1)

# %%
most_dots
# Out:
#           bowler  dot_balls
# 0          Siraj         81
# 1         Chahar         81
# 2  Khaleel Ahmed         76
# 3      Hazlewood         68
# 4    Bhuvneshwar         62
# 5     Yash Dayal         59
# 6          Boult         58
# 7  Anshul Kamboj         56
# 8   Harshit Rana         56
# 9   Marco Jansen         55

# %%
plt.figure(figsize=(10, 6))
plt.barh(most_dots['bowler'], most_dots['dot_balls'], color='#74f8fa')
plt.title('Top 10 Bowlers with Most Dot Balls in Powerplay (Overs 1–6)', fontsize=14)
plt.xlabel('Dot Balls')
plt.ylabel('Bowler')
for index, value in enumerate(most_dots['dot_balls']):
    plt.text(value + 1, index, str(value), va='center')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Which bowler has dismissed Virat Kohli the most?

# %%
v_k = df2.query("striker == 'Kohli'").copy()

# %%
v_k.head()
# Out:
#      match_no          date                  venue batting_team bowling_team  \
# 129         1  Mar 22, 2025  Eden Gardens, Kolkata          RCB          KKR
# 130         1  Mar 22, 2025  Eden Gardens, Kolkata          RCB          KKR
# 140         1  Mar 22, 2025  Eden Gardens, Kolkata          RCB          KKR
# 141         1  Mar 22, 2025  Eden Gardens, Kolkata          RCB          KKR
# 143         1  Mar 22, 2025  Eden Gardens, Kolkata          RCB          KKR
#
#      innings  over striker               bowler  runs_of_bat  wide  \
# 129        2   0.5   Kohli        Vaibhav Arora            4     0
# 130        2   0.6   Kohli        Vaibhav Arora            2     0
# 140        2   2.4   Kohli        Vaibhav Arora            4     0
# 141        2   2.5   Kohli        Vaibhav Arora            1     0
# 143        2   3.1   Kohli  Varun Chakaravarthy            1     0
#
#     wicket_type player_dismissed fielder
# 129         NaN              NaN     NaN
# ...

# %%
dismiss_v_k = v_k[['striker','bowler']].value_counts().dropna().reset_index().head(6)
dismiss_v_k
# Out:
#   striker          bowler  count
# 0   Kohli          Chahal     23
# 1   Kohli       Hasaranga     20
# 2   Kohli  Arshdeep Singh     17
# 3   Kohli    Jofra Archer     16
# 4   Kohli            Axar     15
# 5   Kohli  Sandeep Sharma     15

# %%
dismiss_v_k.columns = ['striker','bowler', 'value']

# %%
labels = dismiss_v_k['bowler']
values = dismiss_v_k['value']
explode = [0.1,0,0,0,0,0]
colors = ['#40ebf9','blue','#40f982','#fc0d0d','#de0dfc','#fcf25d']
plt.pie(values, labels=labels, explode=explode, autopct='%1.1f%%', colors=colors,shadow=True)
plt.title('Bowler Has Dismissed Virat Kohli')
plt.tight_layout()
plt.show()
